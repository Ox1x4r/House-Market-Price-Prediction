# %% [markdown]
# # Data Viewing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing_coursework_entire_dataset_23-24.csv")

# %%
data
# Out:
#       No.  longitude  latitude  housing_median_age  total_rooms  \
# 0       1    -122.12     37.70                  17         2488
# 1       2    -122.21     38.10                  36         3018
# 2       3    -122.22     38.11                  43         1939
# 3       4    -122.20     37.78                  52         2300
# 4       5    -122.19     37.79                  50          954
# ..    ...        ...       ...                 ...          ...
# 995   996    -119.30     36.30                  14         3023
# 996   997    -121.70     38.65                  22         1360
# 997   998    -121.92     38.57                  10         1320
# 998   999    -122.00     38.83                  26          272
# 999  1000    -121.21     39.49                  18          697
#
#      total_bedrooms  population  households  median_income  \
# 0             617.0        1287         538         2.9922
# 1             557.0        1445         556         3.8029
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   No.                 1000 non-null   int64
#  1   longitude           1000 non-null   float64
#  2   latitude            1000 non-null   float64
#  3   housing_median_age  1000 non-null   int64
#  4   total_rooms         1000 non-null   int64
#  5   total_bedrooms      991 non-null    float64
#  6   population          1000 non-null   int64
#  7   households          1000 non-null   int64
#  8   median_income       1000 non-null   float64
#  9   median_house_value  1000 non-null   int64
#  10  ocean_proximity     998 non-null    object
# dtypes: float64(4), int64(6), object(1)
# memory usage: 86.1+ KB

# %%
data.dropna(inplace=True)

# %%
data.info
# Out:
# <bound method DataFrame.info of       No.  longitude  latitude  housing_median_age  total_rooms  \
# 0       1    -122.12     37.70                  17         2488
# 1       2    -122.21     38.10                  36         3018
# 2       3    -122.22     38.11                  43         1939
# 3       4    -122.20     37.78                  52         2300
# 4       5    -122.19     37.79                  50          954
# ..    ...        ...       ...                 ...          ...
# 995   996    -119.30     36.30                  14         3023
# 996   997    -121.70     38.65                  22         1360
# 997   998    -121.92     38.57                  10         1320
# 998   999    -122.00     38.83                  26          272
# 999  1000    -121.21     39.49                  18          697
#
#      total_bedrooms  population  households  median_income  \
# 0             617.0        1287         538         2.9922
# ...

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#      No.  longitude  latitude  housing_median_age  total_rooms  \
# 226  227    -118.26     34.06                  33         1950
# 869  870    -122.03     37.35                  16         1156
# 601  602    -117.43     34.02                  33         3084
# 269  270    -118.38     34.03                  36         2101
# 117  118    -124.19     40.73                  21         5694
# ..   ...        ...       ...                 ...          ...
# 386  387    -118.07     33.86                  31         2943
# 745  746    -116.95     32.81                  15         2619
# 574  575    -118.03     33.77                  21         3803
# 394  395    -118.13     33.78                  31         3039
# 496  497    -121.00     39.26                  14          810
#
#      total_bedrooms  population  households  median_income ocean_proximity  \
# 226          1047.0        3707        1012         1.7238       <1H OCEAN
# ...

# %%
train_data.hist(figsize=(15, 10))
# Out:
# array([[<Axes: title={'center': 'No.'}>,
#         <Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>],
#        [<Axes: title={'center': 'housing_median_age'}>,
#         <Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>],
#        [<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>],
#        [<Axes: title={'center': 'median_house_value'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.drop(train_data.columns[9], axis=1).corr(), annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# # Data Processing

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'No.'}>,
#         <Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>],
#        [<Axes: title={'center': 'housing_median_age'}>,
#         <Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>],
#        [<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>],
#        [<Axes: title={'center': 'median_house_value'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.drop(train_data.columns[9], axis=1).corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# # Feature Engineering

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.drop(train_data.columns[9], axis=1).corr(), annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# # Linear Model

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

reg = LinearRegression()

reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
reg.score(x_test, y_test)
# Out:
# 0.6918033679793407

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predicted_prices, alpha=0.5, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', lw=2)
plt.xlabel('Actual House Prices')
plt.ylabel('Predicted House Prices')
plt.title('Actual vs. Predicted House Prices (Linear Regression)')
plt.show()

# %% [markdown]
# # Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.7345502273993264

# %%
predicted_prices_forest = forest.predict(x_test)

plt.figure(figsize=(10, 6))
plt.scatter(y_test, predicted_prices_forest, alpha=0.5, color='green')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', lw=2)
plt.xlabel('Actual House Prices')
plt.ylabel('Predicted House Prices')
plt.title('Actual vs. Predicted House Prices (Random Forest Regression)')
plt.show()

# %% [markdown]
# # Gradient Boosting Model

# %%
from sklearn.ensemble import GradientBoostingRegressor

gradient_boosting = GradientBoostingRegressor()

gradient_boosting.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
gradient_boosting_score = gradient_boosting.score(x_test, y_test)
gradient_boosting_score
# Out:
# 0.7116497867785799

# %%
predicted_prices_gradient_boosting = gradient_boosting.predict(x_test)

plt.figure(figsize=(10, 6))
plt.scatter(y_test, predicted_prices_gradient_boosting, alpha=0.5, color='orange')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', lw=2)
plt.xlabel('Actual House Prices')
plt.ylabel('Predicted House Prices')
plt.title('Actual vs. Predicted House Prices (Gradient Boosting Regression)')
plt.show()
